# %%
local_root = "../VinDr"

# %%
# !mc alias list
# Out:
# ]11;?\
# gcs
#   URL       : https://storage.googleapis.com
#   AccessKey : YOUR-ACCESS-KEY-HERE
#   SecretKey : YOUR-SECRET-KEY-HERE
#   API       : S3v2
#   Path      : dns
#   Src       : /home/onyxia/.mc/config.json
#
# local
#   URL       : http://localhost:9000
#   AccessKey :
#   SecretKey :
#   API       :
#   Path      : auto
#   Src       : /home/onyxia/.mc/config.json
#
# play
#   URL       : https://play.min.io
#   AccessKey : Q3AM3UQ867SPQQA43P2F
#   SecretKey : zuf+tfteSlswRu7BJ86wekitnifILbZam1KYY3TG
#   API       : S3v4
#   Path      : auto
#   Src       : /home/onyxia/.mc/config.json
#
# s3
#   URL       : https://minio.lab.sspcloud.fr
#   AccessKey : 20HXHI9BG3Y6EAK7N3CQ
#   SecretKey : +qvG0IVoW9tHGcEAnmDoCZQwupw0mYk+xxzgp3Zr
#   API       : S3v4
#   Path      :
#   Src       : env
#
# s3
#   URL       : https://s3.amazonaws.com
#   AccessKey : YOUR-ACCESS-KEY-HERE
#   SecretKey : YOUR-SECRET-KEY-HERE
#   API       : S3v4
#   Path      : dns
# ...

# %%
# !echo $AWS_ACCESS_KEY_ID
# !echo $AWS_SECRET_ACCESS_KEY
# !echo $AWS_SESSION_TOKEN
# !echo $MC_HOST_s3
# Out:
# VKXIKJGTKHMU4RXM1ELQ
# NCV+DsKr2G2qOaS4iUMnOgq5P7GRDCip+cHwnxXq
# eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCJ9.....YpQbHZ6bYPX0jUXSLF82AKEzyYmzAy2dqlrmRpNWebgKvB5JRI8JAptNdQOr2FxMAjUdxCx5pTAk7ez7jTyTug
# https://NOUVELLE_ACCESS_KEY:NOUVELLE_SECRET_KEY:NOUVEAU_SESSION_TOKEN@minio.lab.sspcloud.fr

# %%
import os

os.environ["AWS_ACCESS_KEY_ID"] = "VKXIKJGTKHMU4RXM1ELQ"
os.environ["AWS_SECRET_ACCESS_KEY"] = "NCV+DsKr2G2qOaS4iUMnOgq5P7GRDCip+cHwnxXq"
os.environ["AWS_SESSION_TOKEN"] = "eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCJ9.....YpQbHZ6bYPX0jUXSLF82AKEzyYmzAy2dqlrmRpNWebgKvB5JRI8JAptNdQOr2FxMAjUdxCx5pTAk7ez7jTyTug"
os.environ["AWS_DEFAULT_REGION"] = "us-east-1"
os.environ["AWS_S3_ENDPOINT"]= "minio.lab.sspcloud.fr"
os.environ["MC_HOST_s3"] = "https://VKXIKJGTKHMU4RXM1ELQ:NCV+DsKr2G2qOaS4iUMnOgq5P7GRDCip+cHwnxXq:eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCJ9.....YpQbHZ6bYPX0jUXSLF82AKEzyYmzAy2dqlrmRpNWebgKvB5JRI8JAptNdQOr2FxMAjUdxCx5pTAk7ez7jTyTug@minio.lab.sspcloud.fr"

# %%
# !mc ls s3/dimitri/stat_app/
# !mc ls s3/dimitri/stat_app/VinDr
# Out:
# ]11;?\
# [2026-01-27 14:08:49 UTC]    39B STANDARD .keep
# [2026-04-22 12:52:05 UTC]     0B CMMD2022/
# [2026-04-22 12:52:05 UTC]     0B VinDr/
# [2026-04-22 12:52:05 UTC]     0B VinDr_transforme/
# [2026-04-22 12:52:05 UTC]     0B miniddsm2/
# [2026-04-22 12:52:05 UTC]     0B nouveau_dataset_mini_ddsm_700_700/
# [2026-04-22 12:52:05 UTC]     0B vindr_restructure/
# ]11;?\
# [2026-02-19 11:02:23 UTC] 2.7MiB STANDARD SHA256SUMS.txt
# [2026-02-19 11:02:21 UTC] 2.7MiB STANDARD breast-level_annotations.csv
# [2026-02-19 11:02:18 UTC] 3.3MiB STANDARD finding_annotations.csv
# [2026-04-22 12:52:10 UTC]     0B images_png/

# %%
# !mc mirror \
"s3/dimitri/stat_app/VinDr" \
"../VinDr/"
# Out:
# ]11;?\
#  0 B / ? ┃░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░▓┃
#  0 B / ? ┃░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░▓┃
#  0 B / ? ┃░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░▓┃
#  0 B / ? ┃░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░▓┃
#  0 B / ? ┃░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░▓┃
#  0 B / ? ┃░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░▓┃
#  0 B / ? ┃░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░▓┃
#  0 B / ? ┃░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░▓┃
#  0 B / ? ┃░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░▓┃
#  0 B / ? ┃░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░▓┃
#  0 B / ? ┃░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░▓┃
# ...
