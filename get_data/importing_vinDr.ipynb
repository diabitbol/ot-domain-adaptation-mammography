# %%
local_root = "../VinDr"

# %%
# !mc ls s3/dimitri/stat_app/
# !mc ls s3/dimitri/stat_app/VinDr_transforme
# Out:
# ]11;?\mc: Configuration written to `/home/onyxia/.mc/config.json`. Please update your access credentials.
# mc: Successfully created `/home/onyxia/.mc/share`.
# mc: Initialized share uploads `/home/onyxia/.mc/share/uploads.json` file.
# mc: Initialized share downloads `/home/onyxia/.mc/share/downloads.json` file.
# [2026-01-27 14:08:49 UTC]    39B STANDARD .keep
# [2026-04-01 15:11:12 UTC]     0B CMMD2022/
# [2026-04-01 15:11:12 UTC]     0B VinDr/
# [2026-04-01 15:11:12 UTC]     0B VinDr_transforme/
# [2026-04-01 15:11:12 UTC]     0B miniddsm2/
# [2026-04-01 15:11:12 UTC]     0B nouveau_dataset_mini_ddsm_700_700/
# [2026-04-01 15:11:12 UTC]     0B vindr_restructure/
# ]11;?\[2026-04-01 15:11:18 UTC]     0B VinDr_transforme/

# %%
# !mc mirror \
"s3/dimitri/stat_app/vindr_restructure" \
"../VinDr_restructure/"
# Out:
# ...cdc4dc.png: 4.20 GiB / 4.20 GiB ┃▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓┃ 198.93 MiB/s 21s
