# %%
local_root = "../miniddsm2"

# %%
# !mc ls s3/dimitri/stat_app/
# !mc ls s3/dimitri/stat_app/miniddsm2
# Out:
# ]11;?\[2026-01-27 14:08:49 UTC]    39B STANDARD .keep
# [2026-03-31 22:20:12 UTC]     0B CMMD2022/
# [2026-03-31 22:20:12 UTC]     0B VinDr/
# [2026-03-31 22:20:12 UTC]     0B VinDr_transforme/
# [2026-03-31 22:20:12 UTC]     0B miniddsm2/
# [2026-03-31 22:20:12 UTC]     0B nouveau_dataset_mini_ddsm_700_700/
# [2026-03-31 22:20:12 UTC]     0B vindr_restructure/
# ]11;?\[2026-03-31 22:20:18 UTC]     0B Data-MoreThanTwoMasks/
# [2026-03-31 22:20:18 UTC]     0B MINI-DDSM-Complete-JPEG-8/
# [2026-03-31 22:20:18 UTC]     0B MINI-DDSM-Complete-PNG-16/

# %%
# !mc mirror \
"s3/dimitri/stat_app/nouveau_dataset_mini_ddsm_700_700" \
"../miniddsm"
# Out:
# ...e_3665.jpg: 869.98 MiB / 869.98 MiB ┃▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓┃ 144.28 MiB/s 6s
