# %%
# !pip install kagglehub
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [kagglehub]/3 [kagglesdk]
# ...

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("huuthocs/vindr-mammo-mammo-mass-segmentation-dataset")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 3.06G/3.06G [10:30<00:00, 5.22MB/s]
# Extracting files...
# Path to dataset files: /home/onyxia/.cache/kagglehub/datasets/huuthocs/vindr-mammo-mammo-mass-segmentation-dataset/versions/4

# %%
# !mc mirror --retry --skip-errors --summary \
"/home/onyxia/.cache/kagglehub/datasets/huuthocs/vindr-mammo-mammo-mass-segmentation-dataset/versions/4" \
"s3/jbohn-ensae/stat_app"
# Out:
# ]11;?\┌──────────┬─────────────┬──────────┬─────────────┐
# │ Total    │ Transferred │ Duration │ Speed       │
# │ 2.18 GiB │ 2.18 GiB    │ 01m00s   │ 36.82 MiB/s │
# └──────────┴─────────────┴──────────┴─────────────┘
