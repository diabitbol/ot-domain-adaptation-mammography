# %%
local_root = "../VinDr"

# %%
# !mc ls s3/dimitri/stat_app/
# !mc ls s3/dimitri/stat_app/VinDr
# Out:
# ]11;?\[2026-01-27 14:08:49 UTC]    39B STANDARD .keep
# [2026-03-31 11:07:17 UTC]     0B CMMD2022/
# [2026-03-31 11:07:17 UTC]     0B VinDr/
# [2026-03-31 11:07:17 UTC]     0B miniddsm2/
# ]11;?\[2026-02-19 11:02:23 UTC] 2.7MiB STANDARD SHA256SUMS.txt
# [2026-02-19 11:02:21 UTC] 2.7MiB STANDARD breast-level_annotations.csv
# [2026-02-19 11:02:18 UTC] 3.3MiB STANDARD finding_annotations.csv
# [2026-03-31 11:07:22 UTC]     0B images_png/

# %%
# !mc mirror \
"s3/dimitri/stat_app/VinDr" \
"../VinDr/"
# Out:
# ...57212e.png: 7.72 GiB / 7.72 GiB ┃▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓┃ 300.34 MiB/s 26s

# %%
# !ls -la ./miniddsm2
# !ls -la ./miniddsm2/MINI-DDSM-Complete-JPEG-8 | head
# Out:
# total 12
# drwxr-sr-x 3 onyxia users 4096 Mar 31 11:03 .
# drwxrwsr-x 7 onyxia users 4096 Mar 31 11:12 ..
# drwxr-sr-x 5 onyxia users 4096 Mar 31 11:04 MINI-DDSM-Complete-JPEG-8
# total 1576
# drwxr-sr-x   5 onyxia users    4096 Mar 31 11:04 .
# drwxr-sr-x   3 onyxia users    4096 Mar 31 11:03 ..
# drwxr-sr-x 673 onyxia users   16384 Mar 31 11:04 Benign
# -rw-r--r--   1 onyxia users 1150890 Mar 31 11:04 BoundaryMask.png
# drwxr-sr-x 681 onyxia users   12288 Mar 31 11:04 Cancer
# -rw-r--r--   1 onyxia users  411637 Mar 31 11:04 DataWMask.xlsx
# drwxr-sr-x 604 onyxia users   12288 Mar 31 11:04 Normal
